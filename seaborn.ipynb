# %%
import seaborn as sns
import pandas as pd

# %%
dataset=sns.load_dataset('tips')
dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data=dataset.iloc[:,[0,1,6]]

# %%
data.corr() # positive corelation states that value is increasing with increasing output and negative vice versa corealltion range 
# is from -1 to 1.
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
sns.jointplot(x='tip',y='total_bill',data=dataset,kind='hex')

# %%
sns.jointplot(x='tip',y='total_bill',data=dataset,kind='reg')

# %%
sns.pairplot(dataset)
# Out:
# C:\Users\dhruv\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(dataset,hue='sex')
# Out:
# C:\Users\dhruv\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.distplot(dataset['tip'],kde=False,bins=10)
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_10488\1569010676.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['tip'],kde=False,bins=10)
# <Axes: xlabel='tip'>

# %%
dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x='sex', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='smoker', data=dataset)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='time', data=dataset)
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.countplot(x='day', data=dataset)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.barplot(y='total_bill',x='sex',data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sum_total_bill=dataset['total_bill']
sum_total_bill=sum(sum_value)
sum_total_bill
# Out:
# 4827.770000000001

# %%
# count = total male counts out of total peoples
length = len(dataset)
count=0
sum_total_bill_males=0
for n in range(length):
    if dataset['sex'][n]=='Male':
        count+=1 
        sum_total_bill_males += dataset['total_bill'][n]

average_male=sum_total_bill_males/count
sum_total_bill_females=sum_total_bill-sum_total_bill_males
average_female=sum_total_bill_females/(length-count)

[average_male,average_female]

#so above bar graph bascially represents the value of total bill paid by man in dataset divided by total number of male and its 
#same is with women or female.
# Out:
# [20.744076433121034, 18.056896551724126]

# %%
sns.barplot(y='total_bill',x='smoker',data=dataset)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
# count = total male counts out of total peoples
length = len(dataset)
smoker_count=0
sum_total_bill_smoker=0
for n in range(length):
    if dataset['smoker'][n]=='Yes':
        smoker_count+=1 
        sum_total_bill_smoker += dataset['total_bill'][n]

non_smoker_count=length-smoker_count
sum_total_bill_non_smoker=sum_total_bill-sum_total_bill_smoker
[smoker_count,sum_total_bill_smoker] , [non_smoker_count,sum_total_bill_non_smoker]

print(f"average of smokers bill is {sum_total_bill_smoker/smoker_count}\n\naverage of non smoker bill is {sum_total_bill_non_smoker/non_smoker_count}")

#so above bar graph bascially represents the value of total bill paid by man in dataset divided by total number of male and its 
#same is with women or female.
# Out:
# average of smokers bill is 20.756344086021507
#
# average of non smoker bill is 19.18827814569537

# %%
dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(y='total_bill',x='day',data=dataset)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# for days
money_count=0
count=0
for n in range(len(dataset)):
    if dataset['day'][n] == 'Thur':
        count+=1 
        money_count += dataset['total_bill'][n]

count,money_count
money_count/count
# Out:
# 17.682741935483865

# %%
# for time
money_count=0
count=0
for n in range(len(dataset)):
    if dataset['time'][n] == 'Lunch':
        count+=1 
        money_count += dataset['total_bill'][n]

count,money_count
money_count/count
# Out:
# 17.16867647058823

# %%
sns.barplot(y='total_bill',x='time',data=dataset)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
# box plot and violin plot is remaining for now need to understand joint plot, dist plot and pair plot
